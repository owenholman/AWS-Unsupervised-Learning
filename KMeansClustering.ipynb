# %% [markdown]
# **Group Assignment Cover Page**
#
# Group Number/Team Name: CloudML Visionaries
#
#
#
# |                            |            |           |           |
# | -------------------------- | ---------- | --------- | --------- |
# | Last Name (Alphabetically) | First Name | Student # | Section # |
# | Bugeja                     | Matthew    | 20204487  | 001       |
# | Holman                     | Owen       | 20202892  | 002       |
# | Kim                        | SongErn    | 20206954  | 002       |
# | Wheeler                    | Cameron    | 20230795  | 002       |
# |                            |            |           |           |
# |                            |            |           |           |
# |                            |            |           |           |
# |                            |            |           |           |
# |                            |            |           |           |
#
#
#
# |                                                                                                                                                                            |   |   |   |
# | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | - | - | - |
# |
# Course Title:  Analytics & AI for BusinessesCourse Number:  COMM493Assignment Title: TEAM: KMeans Algorithm Professor: Shaun Cahill
#
#
#
#
#
#
#
#
#
# I (We) certify that this submission is my (our) original work. I (We) have read the guidelines on Academic Integrity at https\://smith.queensu.ca/about/academic\_integrity/, and understand that any violation of academic integrity is a serious offense within the university community.
#
# **Part 1: Business Case**
#
# **Business Context**
#
# The business we will be focusing on is Novel Idea, a local independently owned bookstore located in downtown Kingston, Ontario. This little bookstore has been serving the community since 1988. They sell new fiction & non-fiction, including hard-to-find titles by local authors. The business model revolves around providing personalized service, fostering community engagement, and promoting love for reading and learning. Recognizing the importance of adapting to changing consumer preferences, Novel Idea maintains a strong online presence, allowing customers to request books for purchase through its website.
#
# **Opportunity Description**
#
# The opportunity that Novel Idea Kingston can exploit involves better identifying the different segments of its customers, and tailoring its operations to both improve sales and reduce costs. Currently, the business offers a wide array of books from every genre, with little bias in inventory volume between genres. However, by determining the demographic characteristics of its various customers and the qualities of their favourite books, it can alter its inventory levels, store layout, and marketing.
#
# The potential impact of adapting its operations to its customers and their needs is numerous. First, they will see increased sales, as customers are more likely to purchase books that are a better fit for their segment and that are similar to books that they have historically enjoyed. The store will expand the breadth and number of copies of books that fit better with their largest segments. Second, by identifying the specific books and genres that are not in line with any of the customer segments, Novel Idea can reduce its stock and therefore reduce inventory carrying costs. Third, the store can alter its marketing strategy by offering better recommendations via email and other mediums, driving increased customer satisfaction and engagement. Finally, by amalgamating the prior points, they can reorganize the physical space within the store to increase the accessibility of books that best fit the largest customer segments.
#
# KMeans can be used to exploit the opportunity by determining the characteristics of the small local bookstore’s segments, including information about customers and their preferred books. This algorithm can identify the optimal number of clusters without overfitting the data, with each cluster representing a particular segment that is unique to its Kingston customer base. Moreover, by inputting new data about a possible incoming book, KMeans can determine how well it fits within its target segments - driving informed decisions on whether to order the book and its quantity.
#
# **Solution Description**
#
# Once Novel Idea Kingston has identified its customers' various segments and book preferences, it can optimize its in-store layout. First, this involves changing the composition of their inventory based on the size of each segment and their preferred books. They can hold more copies and a broader selection of books that their largest segments prefer while holding fewer copies and a smaller selection of books that don’t match their target segments. Moreover, they can reorganize the store to keep the books preferred by the larger segments near the front of the store and in more accessible areas. Finally, they can tailor their marketing - both online and in the store windows - toward their largest segments.
#
# From a customer experience perspective, this will drive value to the business by better serving the needs of its target demographic. By offering a wider selection of books whose themes are well-loved by its largest segments, they will boost sales. Customers will be more satisfied with the products offered by the business. Those with positive experiences will be more engaged by being more likely to return to the store, as well as by attracting new customers through word-of-mouth marketing with their friends. They will also be more likely to engage in post-sale book reviews to further enhance the business’s algorithm and their future experiences.
#
# Operationally, the business will not only see increased sales as described above, but also reduced costs. Unlike perishable goods, unpopular books often sit on shelves for a long time - even up to 3 months. By limiting the selection of books from genres belonging to smaller segments, Novel Ideas Kingston will reduce its inventory carrying costs. Rather, the precious and limited space in the bookstore will be reallocated toward the larger target segments.
#
# **Proof of Concept Description**
#
# The proof of concept (POC) uses a KMeans clustering algorithm to identify different customer segments based on customer book reviews. It is able to identify the optimal number of clusters (segments) to group each review, and graphically represent the results. Then, based on new input data of a book review - which includes data about the book and the reviewer - it can classify the new review into the closest cluster and determine how far that review is from the cluster centroid. This tool concretely proves that the proposed solution will add value to the business.
#
# The values of the features of a particular centroid represent the typical customer of that segment. Each new customer that walks in the door will have characteristics that are some distance away from the closest centroid. Although they will be classified to the closest centroid, the distance to that centroid is relevant to understanding how well they will be satisfied by the business’ segmentation and resulting product offering. By using the algorithm to create the optimal number of centroids, customers are less likely to be outliers (far from the nearest cluster) and be unsatisfied with the offered books. Moreover, in clusters that are larger (that have more reviews), even if they are broad, the store will carry a broader selection of books that pertain to that cluster. Overall, the POC proves that customers will be more satisfied because the business can tailor its product offerings based on the model’s resulting insights. When customers browse the store’s books, they will feel like the business truly understands their preferences.
#
# As mentioned, the POC is capable of determining the distance that a review is from the nearest centroid (or typical customer of a segment). With the graphical representation as well as by testing potential books and customer data against the algorithm, Novel Ideas Kingston can ascertain whether or not a book will be a good fit for a particular segment. If a book is far from any of the segments, it makes sense for the business not to carry that book in stores. This can help reduce ordering costs and inventory carrying costs. In terms of the business’s workflows, this shifts the inventory selection decision away from the recommendations of the online general public or a single employee, and toward the collective demographic of the store’s customers. Although using the solution to determine whether a book should be ordered or not will likely take as much time (if not more) than the previous book selection process, the decisions will be more informed and more profitable.
#
# The selected dataset is a collection of book ratings. There are 5635 reviews, with each row of the dataset representing a review of a particular book. Each review includes data about the book and the reviewer, encompassed by the following columns:
#
# - User-ID: a unique identifier for each review
#
# - ISBN: the unique numerical code of the book, which is standard public information by which a book can be found online
#
# - Book-Rating: an integer score out of 10 representing the reviewer’s review of the book
#
# - Book-Title: the string title of the book
#
# - Book-Author: the string author of the book
#
# - Year-Of-Publication: the integer year that the book was published
#
# - Publisher: the string publisher of the book
#
# - Age: the age of the reviewer
#
# - Country: the country from which the reviewer comes from
#
# - Author\_Numerical: a one-hot encoded integer of the range of book authors
#
# Of course, these features are not yet processed and cleaned for the purposes of the proof of concept. String columns will need to be filtered, one-hot encoded, and/or dropped, and some features have no explanatory power toward a customer segment. However, in concept, the dataset represents the opportunity at its core: understanding how different customers perceive different books. The age, country, and rating features are adequate to describe a particular reviewer, although the final solution can collect additional pertinent data such as their gender, occupation, and favourite genre as well. On the other hand, the remaining features pertain to the book itself - the only additional column to be added to the final solution would be the book’s genre.
#
# **Business Changes**
#
# The following process modification plan will be followed to implement the solution:
#
# 1. Ongoing Data Collection
#
# The first step to understanding its segments is to collect reviews of books that the store currently sells. This will be done through a form that is easily accessible through the website, as well as in-store. Offering the form in-store is tailored to remind customers to fill it out, and is tailored to customers who may be older or have an aversion to the Internet (since they’re readers!). To remind customers to fill out the form online, paper bookmarks will be given at each sale - these bookmarks will let customers know the purposes of the book review forms (to enhance the customer experience!) and outline instructions on how to do so. This process will be ongoing, as more reviews will provide more accurate insights and reflect changing preferences over time. To further incentivize customers to do reviews, the store will offer store credit for future purchases.
#
# 2. Data Training Process
#
# Once a sufficient 500 reviews are compiled, a “beta” algorithm mimicking the proof of concept will be created by a data analyst. The first rendition of the solution will show initial insights into the different customer segments and their book preferences. Novel Ideas Kingston will begin reorganizing the store composition to feature the largest segments’ favourite books near the front of the store. The model will be re-trained for every additional 500 reviews that are received, to increase accuracy and further separate the segments into different clusters. This iterative process will allow the bookstore to test how well the solution is working, and if necessary, adjust the fields of the form to better sequester customer segments.
#
# 3. New Book Selection Process
#
# Currently, new book selections are based on recommendations from staff and online reviews for new books. The solution adds a step to this process to determine where in the store books should be placed and to ensure that added books will be liked by a specific customer segment. This step involves inputting the book data into the algorithm along with the customer data of a particular segment: the resulting distance from the centroid will be used as a proxy for how well the book fits the needs of that segment. The graphical output will also help Novel Ideas Kingston to understand the fit, as some segments may be broader than others. The key is to ensure that a book is not a complete outlier - it may still be okay to order the book if it lies on the border of two similar segments. This will be done each time a new book is suggested to be added to the catalogue, estimated to be 5 times per month.
#
# **Development Costs**
#
# Fixed Costs:
#
# 1 Data Scientist: $50/hour; hired for two 40-hour workweeks to create the algorithm, then 1 day on-hire every 500 reviews to retrain the model.
#
# Total Fixed Cost: $4,000 for setup, $400 for subsequent re-training
#
# Variable Costs:
#
# |                                                          |                                      |
# | -------------------------------------------------------: | ------------------------------------ |
# |                                      **_AWS SageMaker_** |  ****                                |
# |                                          _Instance Type_ | ml.c5.12xlarge                       |
# |                              _Number of data scientists_ | 1                                    |
# | _Number of Studio Notebook instances per data scientist_ | 1                                    |
# |                        _Studio Notebook hour(s) per day_ | 1 _(each time a new book is tested)_ |
# |                       _Studio Notebook day(s) per month_ | 5 _(test 5 books per month)_         |
# |                                           _Monthly Cost_ | 12.24 USD                            |
#
# |                                     |                                 |
# | ----------------------------------: | ------------------------------- |
# |        **_AWS SageMaker Training_** |  ****                           |
# | _Number of training jobs per month_ | 1 (for each 500 new reviews)    |
# |       _Number of instances per job_ | 6 (incl. hyperparameter tuning) |
# |      _Hour(s) per instance per job_ | 1                               |
# |                      _Monthly Cost_ | 2.87 USD                        |
#
# |                  |                           |
# | ---------------: | ------------------------- |
# | **_ML Storage_** |  ****                     |
# |           _Type_ | General Purpose SSD (gp2) |
# |         _Amount_ | 5 GB per month            |
# |   _Monthly Cost_ | 0.70 USD                  |
#
# Total Monthly Variable Cost: 15.81 USD
#
# **Development Timeline**
#
# Fixed Time Investments:
#
# Labour: 80 hours to develop the solution, and 8 hours on-demand each time the algorithm is to be re-trained.
#
# Variable Time Investments:
#
# Model Training: >1 hour to train compiled book review data
#
# Data Collection: 1-2 months to receive enough sufficient reviews to train the data the first time
#
# Data Cleaning: 16 hours (2 days) to handle missing and inconsistent data
#
# Data Preparation: 24 hours (3 days) to standardize and encode the data to allow for processing.
#
# **Cost-Benefit Analysis**
#
# **Costs:**
#
# |                                     |                                        |             |
# | ----------------------------------- | -------------------------------------- | ----------- |
# | Cost Category                       | Description                            | Cost        |
# | Development Costs                   |                                        |             |
# | Data Scientist Labor                | 80 hours at $50/hour                   | $4,000      |
# | Operating Costs (Monthly)           |                                        |             |
# | AWS SageMaker (Instance & Training) | Model inference and training           | $15.11      |
# | ML Storage                          | General Purpose SSD Storage            | $0.70       |
# | Data Scientist Labor (Monthly)      | 8 hours/month for retraining model     | $400        |
# | **Total Monthly Costs**             |  ****                                  | **$415.81** |
# | **Total Initial Costs**             | **Includes initial development labor** | **$4,000**  |
#
# **Benefits:**
#
# Revenue boosts and cost savings are achieved through an expanded sales volume and reduced inventory expenses, created by offering a broader selection of books targeted toward the company’s major segments.
#
# |                                          |      |                |
# | :--------------------------------------: | ---- | -------------- |
# | **Projected Revenue/ Cost Saving (CAD)** |      | **MoM Growth** |
# |                  Month 1                 | 500  |                |
# |                  Month 2                 | 670  | 34%            |
# |                  Month 3                 | 780  | 16%            |
# |                  Month 4                 | 840  | 8%             |
# |                  Month 5                 | 900  | 7%             |
# |                  Month 6                 | 940  | 4%             |
# |                  Month 7                 | 980  | 4%             |
# |                  Month 8                 | 1060 | 8%             |
# |                  Month 9                 | 1100 | 4%             |
# |                   Total                  | 7770 |                |
#
# _ROI = ((total\_revenue\_savings - total\_cost) / total\_cost) \* 100_
#
# _ROI = 7770-(417\*9+4000)/417\*9+4000 = (17/ 7754) \* 100 = 0.219%_
#
# **_Breakeven in 9 Months_**
#
# |              |        |
# | ------------ | ------ |
# | 9 Months ROI | 0.219% |
#
# **Intangible Benefits:**
#
# Enhanced Customer Experience: Personalizing the shopping experience enhances customer satisfaction by creating a welcoming environment that meets their preferences, making them feel valued and understood.
#
# Brand Loyalty and Reputation: Consistently meeting customer preferences boosts brand loyalty and reputation, encouraging repeat visits and recommendations through word-of-mouth.
#
# Employee Satisfaction and Efficiency: Data-driven insights improve employee satisfaction by reducing time spent on inventory management (i.e., getting rid of unsold books) and increasing time for customer engagement and other productive activities.
#
# **Change Management Plan**
#
# **Stakeholder Engagement:**
#
# Identified Stakeholders:
#
# - Store Owner: As the principal decision-maker, responsible for overseeing the tool's implementation and integration into store operations.
#
# - Bookstore Employees: Directly interacting with customers and implementing changes in store layout and inventory based on new data insights.
#
# - Customers: The buying process would be changed and better recommendations would be offered.
#
# Communication Strategies:
#
# - Initial Briefing: Conduct a brief session to introduce the tool's capabilities and its potential impact on store operations and customer experience.
#
# - Regular Updates: Utilize end-of-day wrap-ups for ongoing communication about tool usage and to address any immediate questions or observations from the staff.
#
# - Marketing Strategy (See Below): Develop a marketing strategy to communicate the benefits of the new tool.
#
# **Training for Employees:**
#
# Training Program:
#
# - Focused Workshop: A concise, focused workshop that covers the basics of AWS SageMaker and how to interpret customer data segments. This includes practical demonstrations on adjusting inventory and marketing efforts based on segmentation insights.
#
# - Interactive Sessions: Hands-on sessions that allow employees to practice entering data and interpreting output, with real scenarios tailored to their daily tasks. This includes being able to analyze the centroid and depict the graph.
#
# - Materials: Step-by-step guides, FAQ sheets, and scenario-based exercises.
#
# Timeframes:
#
# - Initial Training: One comprehensive training session scheduled to last approximately three hours to ensure all staff are comfortable with the new tools.
#
# - Follow-up Support: Scheduled monthly during the first quarter after implementation to address emerging issues and ensure comfortable usage.
#
# **Monitoring and Feedback:**
#
# Monitoring System:
#
# - Performance Metrics: Track metrics like sales volume changes, inventory turnover ratios, and customer return visits to gauge the impact of the segmentation tool.
#
# - Review Sessions: Hold monthly staff meetings focused on discussing the tool’s utility, challenges faced, and success stories or improvements.
#
# Feedback Mechanism:
#
# - Suggestion Box: Introduce a physical or digital suggestion box for customers to give feedback about the store’s new layout and product offering changes.
#
# - Quarterly Reviews: Detailed quarterly review sessions to assess the tool’s effectiveness and decide on any necessary adjustments or additional training needs.
#
# **Marketing Plan**
#
#
# #### Promotion Strategy:<a id="promotion-strategy"></a>
#
# External Communication:
#
# - Social Media Campaigns: Launch regular posts on platforms like Facebook, Instagram, and Twitter to highlight how the new tool enhances customer experiences. Feature thematic content such as “Book of the Week” recommendations based on customer segments.
#
# - Email Campaigns: Send out monthly newsletters that include book recommendations tailored to customer preferences identified through the segmentation tool. Include customer testimonials and special offers for high-interest books.
#
# - Customer Testimonials and Case Studies: Share Customer Success Stories on Social Media.
#
# Customer Success Stories:
#
# - Blog Posts and Videos: Develop content that details specific instances where customers have found books they love, thanks to the tailored approach powered by the segmentation tool.
#
# - Newsletter Features: Regularly feature success stories in email newsletters, reinforcing the value of personalized shopping experiences.
#
#
# #### Launch Timeline:<a id="launch-timeline"></a>
#
# Customer Pilot Program:
#
# - Duration: 2 months initially. Select a small group of frequent customers to introduce them to the new tool, gathering feedback and making necessary adjustments.
#
# Phased Rollout:
#
# - Soft Launch: Following the pilot program, implement a 1-month soft launch targeting specific segments like frequent buyers and local book clubs. This phase allows for further refinement based on broader feedback.
#
# - Full Rollout: Extend the rollout to all customer segments over an additional 2 months, incorporating lessons learned from the soft launch to ensure full readiness and effectiveness.
#
#
# #### Success Metrics:<a id="success-metrics"></a>
#
# Customer Adoption and Engagement:
#
# - To track adoption, inventory per segment will be measured before and after implementation. The incremental sales volume per incremental inventory in a segment will be captured as the adoption rate.
#
# - Monitor engagement levels through tracking how often customers return to use the personalized recommendations.
#
# ROI and Customer Satisfaction:
#
# - Measure the tool’s impact on sales and inventory efficiency to calculate an ROI. Look for a significant reduction in overstock and understock situations.
#
# - Conduct customer satisfaction surveys focusing on the relevance of book recommendations and overall shopping experience. Aim for a steady increase in customer satisfaction scores over the first year.
#
# **Part 4: Advanced Technical Concepts**
#
# **Data Preprocessing and Inspection**
#
# All data preprocessing was completed using python code to manipulate the csv file. The data was inspected and all rows containing missing or invalid data were removed. From there the dataset was further tuned down to only include sales from the country of the target business, ‘Canada’. Once inspected, it was realized the dataset was still too large to draw any actionable conclusions, and finally, only the book reviews from the top 100 Authors in Canada were included in the final dataset.\
# For data visualization, a random sample of 1000 book reviews were selected.
#
# Age Histogram
#
# ![](https://lh7-us.googleusercontent.com/2wVYlPyHEa_t8lR8371MWAgdQ_c5gboFci5Tnr2uq3fK_U4WwbsskR8iQpWAZan9Jj9g-sVBj3rXvUls-FcjXRLvM7B0r1SKTJ_iXue291pv0BxHNPpN-KDmGb5gE5zvWshHfioiFxt31zRJXcyFVgs)
#
# Included within the POC is a histogram visualizing the distribution of ages within the dataset. As seen above, there is a large peak within the 20-30 age range with another peak around the 45-55 age range. This information is valuable for Novel Idea as it can be very beneficial to understand their regular customers and align their book selection with this group. Having demographic information can also be beneficial towards understanding the lifetime value that each customer will have. Improving upon this customer engagement and increasing the chance for customer retention should be a focus for the business as these customers will drive additional value through regular sales. Additionally, having this information can help with understanding the customer segmentation the store is currently dealing with. Focused efforts towards their most popular customer segment can help increase sales and overall profits. Creating personalized marketing campaigns for each customer segment can provide additional value to the company through increased sales and allow Novel Idea to better cater to each individual, increasing customer satisfaction and the chance of their return in the future.
#
# Initial Scatter Plot
#
# When initially visualizing the dataset, a few insights can be extracted regarding the overall customer base. The scatter plot can help describe some of the customer demographic as there is a higher density roughly between the 20-40 age range. This information is beneficial to the store as they can better understand who their target customers should be as the majority of revenues will come from this demographic. Additional insights can be extracted from the range of authors as some have overall lower book ratings, allowing Novel Idea to identify potential authors that may not be beneficial towards sales and taking up extra shelf space. Novel Idea can use information from this visualization to aid in their general inventory selection process and supplement it with the cluster information that will be extracted from the data to help with this process.
#
# **Set the Hyperparameters**
#
# To fully demonstrate this proof of concept,  the “feature\_dim” and “k” hyperparameters were set to 3 and a range of 2-8, respectively. The “epoch” and “mini\_batch\_size” hyperparameters were also tuned. These hyperparameter values are specific to the proof of concept model, and will not be very relevant to Novel Idea. However, the ability to tune these parameters will be very useful to creating the most efficient and accurate prediction model.
#
# For this model the number of epochs was increased from 1 to 2 and the mini batch size was decreased from 5000 to 4000. This increase in the amount of iterations (epochs), results in greater model quality and longer training time. The decrease in mini batch size decreases the required memory and resources, which is meant to slightly counteract the extreme increase in resource usage from the epoch increase. The overall impact this has on the model is an increase in quality, with a trade-off of an increase in resource consumption. These values can be fine tuned when the model is implemented into practice to best fit your cost/benefit needs.
#
# **Advanced Model Performance Analysis**
#
# SSE Score Plot
#
# ![](https://lh7-us.googleusercontent.com/k55d79SmaapLxbsElxQJz7zXcS8hWkrBvM704G0zo512c8Dr5qErFaAyQ7P_vtgA4LqgovvttqIuyvBCGVlqvB2cmd3PXwgPbZV6k6FT0wlKnPf2uoc_7d9Dzm_NO09gWpOuart8s2zVO_MG0P94Im4)
#
# When viewing the initial training SSE scores, we can see that there is not an obvious change in the graph slope and is not an obvious “elbow” shape. There is a noticeable change around 4 and 5 clusters, indicating that the data is best segmented near these clusters. This can show there are 4-5 customer segments based on book ratings, age, and author, allowing for data-driven decisions to be made. When deciding between 4 or 5 clusters, it is important to keep in mind the potential of overfitting when having more clusters, or oversimplification when having less clusters. This can potentially harm the business through having inaccurate customer segmentation, taking away from the additional value that the model can bring. To help address this issue, another plot will be used to find the optimal customer segments. Using the silhouette score will let Novel Idea gain additional insights into the possible customer segments they have, leading to a more personalized approach when addressing customers. However, the elbow plot will still be useful to validate the findings from the silhouette score graph, leading to higher confidence in the number of clusters.
#
# Silhouette Score Plot
#
# ![](https://lh7-us.googleusercontent.com/gaJ1RqdnEEbo6pRse-Hjr_zI_5HbfoMPI9j3FNRDgUC3ZYRnyeswvxfG-nGPfTM_fwFsE01PdWNQNOwRatDeAv7aTV08DgUm43iiQd8jvR1a0FNWYwgZrlAZPaND1AkplhQanljYifNcqTP8X189Yd8)
#
# The silhouette score graph above shows an interesting relationship with the data when determining the number of clusters shown. While initially experiencing a negative slope at the beginning, the graph switches to a positive slope until K = 5. The initial negative slope can indicate potential overfitting when using just 2 clusters. To ensure that there are actionable clusters from the data, we decided to move forward with K = 4, as this best segments the data regarding the author, age, and ratings for the books. With this information, Novel Idea can create targeted marketing strategies to certain author lovers, showing the variety of books they have in stock, along with creating personalized recommendations that can drive additional revenues. As the store collects additional data, they can focus on optimizing their book offerings and drive their personalized recommendations.
#
# Cluster Map
#
# ![](https://lh7-us.googleusercontent.com/gGPldAPXMm6BR2V8W53qyomrrJR8kkbA9VO4UpiURdnaw8JVOSFlcWWu9l7oMVfG9QAOlRLq-pYDM4InNE7XgJSqussimwT3Wc8i1CdDKieXz7WtvGpL577gsFcYEF3YJJKG_lGy6NN5GNHo9e0WLR8)
#
# The graph above can help show the overall clusters that are found through using Author, age, and book rating to help segment customer behaviour. We can recognize that there are a large number of higher book ratings for certain favourite authors. This data can help show that various customers have similar opinions, regardless of age, for favourite authors. From using data like this, Novel Idea can benefit from the model by having more of the author’s books in-stock, leading to higher opportunity for sales, increasing revenue, along with improving upon customer satisfaction. This will make it more likely for customers to return, rather than deciding to order books off online retailers such as Amazon
#
# Deploy the Model
#
# Make Inferences

# %% [markdown]
# # Library Imports and Setup

# %%
# Install the mxnet library required for certain functionalities in SageMaker
# !pip install mxnet

# AWS SageMaker and Boto3
import sagemaker
from sagemaker import get_execution_role, KMeans
from sagemaker.image_uris import retrieve
from sagemaker.model import Model
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer
import boto3
from botocore.exceptions import ClientError
from sagemaker.tuner import IntegerParameter, CategoricalParameter, HyperparameterTuner
from sagemaker.amazon.common import write_numpy_to_dense_tensor
from sagemaker.inputs import TrainingInput

# Data Manipulation
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Libraries
import tarfile
import mxnet as mx
import datetime
import json
import time
from tabulate import tabulate
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split

import io

# %% [markdown]
# # SageMaker Setup and Configuration

# %%
# Initialize a SageMaker Session
# A SageMaker Session helps in managing the interactions with the AWS SageMaker service, such as creating and training models, and deploying endpoints.
sagemaker_session = sagemaker.Session()

# Retrieve the IAM role
# The IAM role is required by SageMaker to access AWS resources (e.g., S3 buckets) on your behalf.
role = get_execution_role()

# Identify the AWS Region of the SageMaker Session
# This information is used to ensure that resources are created in the same region as the SageMaker session.
region = sagemaker_session.boto_region_name

# Create Boto3 Clients for S3 and SageMaker
# These clients enable programmatic access to S3 and SageMaker services for operations like uploading data and creating training jobs.
s3_client = boto3.client('s3')
sagemaker_client = boto3.client('sagemaker')

# Retrieve the Docker image URI for the KMeans algorithm
# This URI is specific to the AWS region and is used to pull the appropriate image for training.
image_uri = retrieve('kmeans', region)

# Define the Default S3 Bucket for SageMaker
# SageMaker requires an S3 bucket to store training data, models, and outputs. Here, we use the session's default bucket.
bucket = sagemaker_session.default_bucket()

# Set the S3 Prefix for Storing Data
# The prefix is used to organize the data in the bucket, making it easier to manage and locate.
prefix = 'sagemaker/canada/kmeans-all'

# Output the IAM Role ARN and AWS Region for verification
print("Execution Role ARN:", role)
print("AWS Region:", region)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# Execution Role ARN: arn:aws:iam::316608326268:role/LabRole
# AWS Region: us-east-1

# %% [markdown]
# # Load and Preprocess the Dataset

# %%
# Step 1: Load the Dataset
# This allows for easy data manipulation and analysis.
df_canada = pd.read_csv('Top_100_Authors_Filtered.csv')

# Step 2: Select Relevant Features
# Focus on the features 'Age', 'Annual Income (k$)', and 'Spending Score (1-100)' for analysis.
df_canada = df_canada[['Author_Numerical', 'Age', 'Book-Rating']]
df_canada = df_canada.sample(n=1000, random_state=42)

# Step 3: Convert Data for Machine Learning
# Convert the selected DataFrame into a NumPy array of type 'float32'.
# This conversion is necessary as most machine learning frameworks work efficiently with NumPy arrays.
data_np = df_canada.values.astype('float32')

# Step 4: Save Preprocessed Data
# Save the preprocessed dataset to a CSV file, without the index.
df_canada.to_csv('canada_data-two-a.csv', index=False)

# Confirming the data has been preprocessed and saved.
print("Preprocessed dataset saved as 'canada_data-two-a.csv'.")

# Display the first few rows of the processed dataset to verify the preprocessing steps.
print(df_canada.head())
# Out:
# Preprocessed dataset saved as 'canada_data-two-a.csv'.
#       Author_Numerical   Age  Book-Rating
# 2121               277  40.0            7
# 915                512  18.0            9
# 2585               959  29.0            8
# 787                424  28.0            7
# 101                347  26.0            8

# %% [markdown]
# # Plot the data

# %%
# Initialize a figure for 3D plotting
fig = plt.figure(figsize=(12, 8))

# Add a 3D subplot to the figure
# '111' indicates 1x1 grid, first subplot. 'projection='3d'' specifies the 3D projection.
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for customer data
# Customers are plotted based on their 'Age', 'Annual Income (k$)', and 'Spending Score (1-100)'
ax.scatter(df_canada['Author_Numerical'], df_canada['Age'], df_canada['Book-Rating'], s=50)

# Set the title of the plot
ax.set_title('Book Review Data')

# Label the axes
ax.set_xlabel('Author (enumerated)')
ax.set_ylabel('Age')
ax.set_zlabel('Book Rating')

# Adjust the layout to ensure everything fits without overlaps
plt.tight_layout()

# Display the plot
plt.show()

# Extract the 'Age' column from the DataFrame
age_data = df_canada['Age']

# Create a histogram
plt.figure(figsize=(12, 8))
plt.hist(age_data, bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # KMeans Model Training

# %%
# Define the range of k values for the KMeans clustering
# This range will determine how many models we train, each with a different number of clusters.
k_values = range(2, 8)

# Initialize lists to keep track of the S3 paths for the trained models and their training job names.
model_paths = []
training_jobs = []

# Set the output path in the S3 bucket for the trained models
# This path will be used to store the output (model artifacts) of each training job.
output_path = f's3://{sagemaker_session.default_bucket()}/sagemaker/canada/kmeans-two/output'

# Iterate over each k value to train a separate KMeans model for that number of clusters
for k in k_values:
    # Generate a unique job name for each training job based on the k value
    job_name = f'kmeans-canada-two-k-{k}'
    
    # Initialize the KMeans estimator from SageMaker with the specific k value
    # Configuration includes instance type, number of instances, and the specified k value.
    kmeans = KMeans(
        sagemaker_session=sagemaker_session,
        role=role,
        instance_count=1,
        instance_type='ml.m5.large',
        k=k,
        output_path=output_path,
        job_name=job_name,
        feature_dim=3,  # Specify the number of features in the input data
    )
    
    # Start the training job for the KMeans model
    # We use 'wait=False' to start each training job asynchronously.
    kmeans.fit(kmeans.record_set(data_np), wait=False)
    training_jobs.append((k, kmeans.latest_training_job.name))

# After initiating all training jobs, we wait for each to complete and collect their model URIs
for k, job_name in training_jobs:
    # Wait for the completion of the training job
    sagemaker_client.get_waiter('training_job_completed_or_stopped').wait(TrainingJobName=job_name)
    
    # Retrieve the S3 URI of the model artifacts for the completed training job
    training_job_description = sagemaker_client.describe_training_job(TrainingJobName=job_name)
    model_s3_uri = training_job_description['ModelArtifacts']['S3ModelArtifacts']
    model_paths.append((k, model_s3_uri))

# Print the S3 paths of the model artifacts for all trained models
# This provides a clear reference to the location of each model for further analysis or deployment.
headers = ['k Value', 'S3 Model Artifact Path']
print(tabulate(model_paths, headers=headers))
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: kmeans-2024-04-15-02-19-33-464
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: kmeans-2024-04-15-02-19-34-190
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# ...

# %% [markdown]
# # Determine K through Elbow Plot

# %%
# List to store the Sum of Squared Errors (SSE) for each value of K
sse_values = []

# Iterate over each trained model's path to calculate SSE
for k, model_path in model_paths:
    try:
        # Download the model artifacts from S3
        local_path = f'/tmp/model-k-{k}.tar.gz'
        s3_client.download_file(sagemaker_session.default_bucket(), model_path.replace(f's3://{sagemaker_session.default_bucket()}/', ''), local_path)
        
        # Extract the model artifacts
        with tarfile.open(local_path) as tar:
            tar.extractall(path=f'/tmp/k-{k}')
        
        # Load the KMeans model parameters
        kmeans_model_params = mx.ndarray.load(f'/tmp/k-{k}/model_algo-1')
        centroids = kmeans_model_params[0].asnumpy()
        
        # Calculate distances from each point to each centroid
        distances = np.sqrt(((data_np - centroids[:, np.newaxis])**2).sum(axis=2))
        
        # Determine the closest centroid for each data point
        closest_centroids = np.argmin(distances, axis=0)
        
        # Calculate SSE for this value of K
        sse = np.sum((data_np - centroids[closest_centroids])**2)
        sse_values.append(sse)
    except Exception as e:
        print(f'Error processing model for K={k}: {e}')

# Create and display the Elbow Plot using seaborn and matplotlib
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(x=[k for k, _ in model_paths], y=sse_values, marker='o')
plt.title('Elbow Plot for Determining Optimal Number of Clusters')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.xticks([k for k, _ in model_paths])
plt.show()

# %% [markdown]
# # Determine K through using Silhouette Method

# %%
# List to store the silhouette scores for each value of K
silhouette_scores = []

# Iterate over each trained model's path to calculate its silhouette score
for k, model_path in model_paths:
    try:
        # Download the model artifacts from S3
        local_path = f'/tmp/model-k-{k}.tar.gz'
        s3_client.download_file(sagemaker_session.default_bucket(), model_path.replace(f's3://{sagemaker_session.default_bucket()}/', ''), local_path)
        
        # Extract the model artifacts
        with tarfile.open(local_path) as tar:
            tar.extractall(path=f'/tmp/k-{k}')
        
        # Load the KMeans model parameters
        kmeans_model_params = mx.ndarray.load(f'/tmp/k-{k}/model_algo-1')
        centroids = kmeans_model_params[0].asnumpy()
        
        # Calculate distances from each point to each centroid
        distances = np.sqrt(((data_np - centroids[:, np.newaxis])**2).sum(axis=2))
        
        # Determine the closest centroid for each data point
        closest_centroids = np.argmin(distances, axis=0)
        
        # Calculate the silhouette score for this value of K
        silhouette_score_value = silhouette_score(data_np, closest_centroids)
        silhouette_scores.append(silhouette_score_value)
    except Exception as e:
        print(f'Error processing model for K={k}: {e}')

# Plot the silhouette scores for different values of K, if available
if silhouette_scores:  # Ensure the list is not empty
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.lineplot(x=[k for k, _ in model_paths], y=silhouette_scores, marker='o')
    plt.title('Silhouette Scores for Determining Optimal Number of Clusters')
    plt.xlabel('Number of Clusters (K)')
    plt.ylabel('Silhouette Score')
    plt.tight_layout()  # Adjust the layout to make sure everything fits without overlap
    plt.show()
else:
    print("No silhouette scores to plot.")

# %% [markdown]
# # Hyperparameter Tuning

# %%
tuning_job_name = tuner.latest_tuning_job.name
sagemaker_client = boto3.client('sagemaker')

# List training jobs for the hyperparameter tuning job
training_jobs_response = sagemaker_client.list_training_jobs_for_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=tuning_job_name
)

# Extract training job names
training_job_names = [job['TrainingJobName'] for job in training_jobs_response['TrainingJobSummaries']]

# Print training job names
print("Training Jobs:")
for job_name in training_job_names:
    print(job_name)
# Out:
# Training Jobs:
# kmeans-240415-0213-006-5cbbbf2d
# kmeans-240415-0213-005-7a77547a
# kmeans-240415-0213-004-b3d0e83f
# kmeans-240415-0213-003-61425bc2
# kmeans-240415-0213-002-8c65a174
# kmeans-240415-0213-001-cb08c728

# %%
for job_name in training_job_names:
    response = sagemaker_client.describe_training_job(TrainingJobName=job_name)
    print(f"Training Job: {job_name}")
    print("Training Job Status:", response['TrainingJobStatus'])
    # Print logs if available
    if 'TrainingJobStatus' in response and response['TrainingJobStatus'] == 'Failed':
        print("Failure Reason:", response['FailureReason'])
# Out:
# Training Job: kmeans-240415-0213-006-5cbbbf2d
# Training Job Status: Failed
# Failure Reason: ClientError: Incorrect configuration or train dataset provided. The value of feature_dim hyperparameter '4' doesn't match train data dimensionality '3'. Please set feature_dim to the number of features in train dataset., exit code: 2
# Training Job: kmeans-240415-0213-005-7a77547a
# Training Job Status: Failed
# Failure Reason: ClientError: Incorrect configuration or train dataset provided. The value of feature_dim hyperparameter '4' doesn't match train data dimensionality '3'. Please set feature_dim to the number of features in train dataset., exit code: 2
# Training Job: kmeans-240415-0213-004-b3d0e83f
# Training Job Status: Failed
# Failure Reason: ClientError: Incorrect configuration or train dataset provided. The value of feature_dim hyperparameter '4' doesn't match train data dimensionality '3'. Please set feature_dim to the number of features in train dataset., exit code: 2
# ...

# %%
# Specify the best K value
best_k = 4

# Initialize KMeans estimator with specified configuration and hyperparameters
kmeans = sagemaker.estimator.Estimator(
    image_uri=image_uri,  # Docker image URI for KMeans algorithm
    role=role,  # IAM role with permissions for SageMaker operations
    instance_count=1,  # Number of EC2 instances for training
    instance_type='ml.m5.large',  # Type of EC2 instance to use for training
    output_path=f's3://{bucket}/{prefix}/output',  # S3 location for saving trained model artifacts
    sagemaker_session=sagemaker_session,  # SageMaker session object
    hyperparameters={
        'k': best_k,  # Desired number of clusters
        'feature_dim': '3'  # Number of features in input data
    }
)

# Define hyperparameter ranges for tuning
hyperparameter_ranges = {
    'extra_center_factor': IntegerParameter(4, 7),
    'init_method': CategoricalParameter(['random', 'kmeans++']),
    'epochs': IntegerParameter(1, 6),
    'mini_batch_size': IntegerParameter(3000, 10000)
}

# Metric to optimize during hyperparameter tuning
objective_metric_name = 'test:msd'

# Split data into training and testing sets
train_data, test_data = train_test_split(data_np, test_size=0.2, random_state=42)

# Convert and upload training data to S3 in recordIO-wrapped protobuf format
buf = io.BytesIO()
write_numpy_to_dense_tensor(buf, train_data, labels=None)
buf.seek(0)
train_key = f'{prefix}/train/train_data.pbr'
s3_client.upload_fileobj(buf, bucket, train_key)
s3_train_data = f's3://{bucket}/{train_key}'

# Convert and upload testing data to S3 in the same format
buf = io.BytesIO()
write_numpy_to_dense_tensor(buf, test_data, labels=None)
buf.seek(0)
test_key = f'{prefix}/test/test_data.pbr'
s3_client.upload_fileobj(buf, bucket, test_key)
s3_test_data = f's3://{bucket}/{test_key}'

# Define training and testing inputs for SageMaker
train_input = TrainingInput(s3_data=s3_train_data, content_type='application/x-recordio-protobuf')
test_input = TrainingInput(s3_data=s3_test_data, content_type='application/x-recordio-protobuf')

# Configure and initialize hyperparameter tuner
tuner = HyperparameterTuner(
    estimator=kmeans,
    objective_metric_name=objective_metric_name,
    hyperparameter_ranges=hyperparameter_ranges,
    objective_type='Minimize',
    max_jobs=10,
    max_parallel_jobs=2
)

# Start hyperparameter tuning job
tuner.fit({'train': train_input, 'test': test_input})
tuner.wait()  # Block until tuning job completes

# Fetch the best model and its hyperparameters
best_estimator = tuner.best_estimator()
print("Best hyperparameters:")
for key, value in best_estimator.hyperparameters().items():
    print(f"{key}: {value}")

# Download the best model artifacts from S3
best_model_s3_uri = best_estimator.model_data
local_path = '/tmp/best_model.tar.gz'
s3_client.download_file(Bucket=bucket, Key=best_model_s3_uri.replace(f's3://{bucket}/', ''), Filename=local_path)

# Extract model parameters
with tarfile.open(local_path) as tar:
    tar.extractall(path='/tmp/best_model')

# Load the KMeans model parameters and compute cluster assignments
kmeans_best_params = mx.ndarray.load('/tmp/best_model/model_algo-1')
centroids_best = kmeans_best_params[0].asnumpy()
distances_best = np.sqrt(((data_np - centroids_best[:, np.newaxis])**2).sum(axis=2))
cluster_labels = np.argmin(distances_best, axis=0)

# Add cluster labels to the original DataFrame
df_canada['Cluster'] = cluster_labels

# Compute model metrics, e.g., Sum of Squared Errors (SSE)
sse_best = np.sum((data_np - centroids_best[cluster_labels])**2)
print(f"Model Metrics for Best Model:\nSSE: {sse_best}")

# Visualization
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot data points, color-coded by cluster assignment
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown']
for i in range(best_k):
    cluster_points = data_np[closest_centroids == i]
    ax.scatter(cluster_points[:, 0], cluster_points[:, 1], cluster_points[:, 2], s=50, color=colors[i % len(colors)], label=f'Cluster {i+1}')

# Plot centroids
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], s=200, color='black', marker='X', label='Centroids')

# Customize the view angle for better understanding of the plot
ax.view_init(elev=20, azim=45)

# Set plot attributes
ax.set_title(f'Book Reviews by Author K={best_k}')
ax.set_xlabel('Author_Numerical')
ax.set_ylabel('Age')
ax.set_zlabel('Book Rating')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# WARNING:sagemaker.estimator:No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# WARNING:sagemaker.estimator:No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# INFO:sagemaker:Creating hyperparameter tuning job with name: kmeans-240415-0223
# ......................................................................................!
# !
#
# 2024-04-15 02:29:09 Starting - Found matching resource for reuse
# 2024-04-15 02:29:09 Downloading - Downloading the training image
# 2024-04-15 02:29:09 Training - Training image download completed. Training in progress.
# 2024-04-15 02:29:09 Uploading - Uploading generated training model
# 2024-04-15 02:29:09 Completed - Resource reused by training job: kmeans-240415-0223-008-3b02e9ff
# Best hyperparameters:
# _tuning_objective_metric: test:msd
# epochs: 6
# ...

# %% [markdown]
# # Model Deployment to SageMaker Endpoint

# %%
# Specify names for the endpoint and its configuration
endpoint_name = 'canada-kmeans-two'
endpoint_config_name = 'canada-kmeans-two'

# Function to wait for endpoint configuration deletion
def wait_for_endpoint_config_deletion(endpoint_config_name):
    print(f'Waiting for endpoint configuration "{endpoint_config_name}" to be deleted...')
    while True:
        try:
            sagemaker_client.describe_endpoint_config(EndpointConfigName=endpoint_config_name)
            time.sleep(5)  # Poll every 5 seconds
        except ClientError as e:
            if e.response['Error']['Code'] == 'ValidationException':
                print(f'Endpoint configuration "{endpoint_config_name}" deleted.')
                break
            else:
                raise

# Check and delete the existing endpoint configuration if it exists
try:
    sagemaker_client.describe_endpoint_config(EndpointConfigName=endpoint_config_name)
    print(f'Endpoint configuration "{endpoint_config_name}" already exists. Deleting...')
    sagemaker_client.delete_endpoint_config(EndpointConfigName=endpoint_config_name)
    wait_for_endpoint_config_deletion(endpoint_config_name)
except ClientError as e:
    if e.response['Error']['Code'] == 'ValidationException':
        print(f'Endpoint configuration "{endpoint_config_name}" does not exist.')

# Function to wait for endpoint deletion
def wait_for_endpoint_deletion(endpoint_name):
    print(f'Waiting for endpoint "{endpoint_name}" to be deleted...')
    while True:
        try:
            sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
            time.sleep(5)  # Poll every 5 seconds
        except ClientError as e:
            if e.response['Error']['Code'] == 'ValidationException':
                print(f'Endpoint "{endpoint_name}" deleted.')
                break
            else:
                raise

# Check and delete the existing endpoint if it exists
try:
    sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
    print(f'Endpoint "{endpoint_name}" already exists. Deleting...')
    sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
    wait_for_endpoint_deletion(endpoint_name)
except ClientError as e:
    if e.response['Error']['Code'] == 'ValidationException':
        print(f'Endpoint "{endpoint_name}" does not exist.')

# Identify the best model based on prior analysis
best_k = 6  # Assuming best_k is determined through prior analysis
best_model_s3_uri = next(path for k, path in model_paths if k == best_k)

# Create a SageMaker Model object with the best model's artifacts
best_model = Model(
    model_data=best_model_s3_uri,
    image_uri=image_uri,
    role=role,
    sagemaker_session=sagemaker_session
)

# Deploy the model to an endpoint
# Note: This operation can take several minutes to complete.
predictor = best_model.deploy(
    endpoint_name=endpoint_name,
    initial_instance_count=1,
    instance_type='ml.m5.large'
)

print(f'Model deployed to endpoint: {endpoint_name}')
# Out:
# INFO:sagemaker:Creating model with name: kmeans-2024-04-15-02-32-40-271
# Endpoint configuration "canada-kmeans-two" does not exist.
# Endpoint "canada-kmeans-two" does not exist.
# INFO:sagemaker:Creating endpoint-config with name canada-kmeans-two
# INFO:sagemaker:Creating endpoint with name canada-kmeans-two
# ----

# %% [markdown]
# # Cluster Associations and Centroids

# %%
# Initialize a Predictor object for the deployed SageMaker endpoint
predictor = Predictor(endpoint_name=endpoint_name, serializer=CSVSerializer())

def get_user_input(prompt):
    """Function to get user input; allows quitting by typing 'quit'."""
    user_input = input(prompt).strip()
    if user_input.lower() == 'quit':
        return None
    return user_input

def validate_and_prompt(feature_name, feature_prompt):
    """Validate and repeatedly prompt until a valid input or 'quit' is entered."""
    while True:
        user_input = get_user_input(feature_prompt)
        if user_input is None:  # User chose to exit
            return None
        try:
            # Ensure input is a positive number for Age, Annual Income, and Spending Score
            # No specific check for Gender as it's not included in this interaction
            value = float(user_input)
            if value > 0:
                return str(value)
            else:
                print(f"Please enter a positive number for {feature_name}.")
        except ValueError:
            print(f"Invalid input. Please enter a number for {feature_name}.")

print("Cluster Prediction Program")
print("Enter the following information for a prediction, or type 'quit' to exit.")

while True:
    # Collect inputs from the user
    age = validate_and_prompt('Author_Numerical', "Enter Author: ")
    if age is None: break
    annual_income = validate_and_prompt('Age', "Enter Age: ")
    if annual_income is None: break
    spending_score = validate_and_prompt('Book-Review', "Enter Book Review: ")
    if spending_score is None: break

    # Prepare the data for prediction
    data = f'{age},{annual_income},{spending_score}\n'

    # Make prediction
    try:
        response = predictor.predict(data)
        # Parse the prediction response
        response_json = json.loads(response)
        cluster = response_json['predictions'][0]['closest_cluster']
        distance = response_json['predictions'][0]['distance_to_cluster']
        # Print the cluster assignment
        print(f"The data point belongs to Cluster {int(cluster)} with a distance of {distance:.2f} to the cluster center.")
    except Exception as e:
        print(f"An error occurred during prediction: {str(e)}")

print("Program exited.")
# Out:
# Cluster Prediction Program
# Enter the following information for a prediction, or type 'quit' to exit.
# Enter Author:  50
# Enter Age:  30
# Enter Book Review:  6
# The data point belongs to Cluster 3 with a distance of 11.64 to the cluster center.
# Enter Author:  quit
# Program exited.

# %% [markdown]
# # Delete the Endpoint and Endpoint Config

# %%
# Prompt for confirmation before proceeding with the deletion
confirmation = input("Are you sure you want to delete the endpoint and endpoint configuration? (yes/no): ")

if confirmation.lower() == 'yes':

    # Function to delete endpoint configuration
    def delete_endpoint_config(endpoint_config_name):
        try:
            sagemaker_client.describe_endpoint_config(EndpointConfigName=endpoint_config_name)
            print(f'Endpoint configuration "{endpoint_config_name}" exists. Deleting...')
            sagemaker_client.delete_endpoint_config(EndpointConfigName=endpoint_config_name)
            print(f'Endpoint configuration "{endpoint_config_name}" deleted successfully.')
        except ClientError as e:
            if e.response['Error']['Code'] == 'ValidationException':
                print(f'Endpoint configuration "{endpoint_config_name}" does not exist.')
            else:
                raise

    # Function to delete the endpoint
    def delete_endpoint(endpoint_name):
        try:
            sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
            print(f'Endpoint "{endpoint_name}" exists. Deleting...')
            sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
            print(f'Endpoint "{endpoint_name}" deleted successfully.')
        except ClientError as e:
            if e.response['Error']['Code'] == 'ValidationException':
                print(f'Endpoint "{endpoint_name}" does not exist.')
            else:
                raise

    # Delete the endpoint configuration
    delete_endpoint_config(endpoint_config_name)

    # Delete the endpoint
    delete_endpoint(endpoint_name)

else:
    print("Deletion cancelled. The endpoint and its configuration were not deleted.")
# Out:
# Are you sure you want to delete the endpoint and endpoint configuration? (yes/no):  yes
# Endpoint configuration "mall-kmeans-two" does not exist.
# Endpoint "mall-kmeans-two" does not exist.
